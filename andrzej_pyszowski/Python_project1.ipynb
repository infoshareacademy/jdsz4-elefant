# %%
import pandas as pd
from pandas import Series, DataFrame
import os
import datetime
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt

# %%
df = pd.read_csv(r"c:/Python\appstore_games.csv")
# df.duplicated(subset = ['ID']).count()
# df.head()

# %%
df['Current Version Release Date']=pd.to_datetime(df['Current Version Release Date'])
df['Original Release Date']=pd.to_datetime(df['Original Release Date'])
df['Update'] = (pd.to_datetime(df['Current Version Release Date']))-(pd.to_datetime(df['Original Release Date']))
df['Update'] = df['Update'] / np.timedelta64(1, 'D')
df.columns
# Out:
# Index(['URL', 'ID', 'Name', 'Subtitle', 'Icon URL', 'Average User Rating',
#        'User Rating Count', 'Price', 'In-app Purchases', 'Description',
#        'Developer', 'Age Rating', 'Languages', 'Size', 'Primary Genre',
#        'Genres', 'Original Release Date', 'Current Version Release Date',
#        'Update'],
#       dtype='object')

# %%
df.rename(columns = {'Average User Rating' : 'Average_User_Rating', 'Age Rating': 'Age_Rating',
       'User Rating Count' : 'User_Rating_Count', 'In-app Purchases' : 'In-app_Purchases', 'Age Rating' : 'Age_Rating'}, inplace = True)

# %%
def trans_age(x):
    if x == '4+':
        return 4
    if x == '9+':
        return 9
    if x == '12+':
        return 12
    if x == '17+':
        return 17
df['Trans_Age'] = df['Age_Rating'].apply(trans_age)

# %%
df['lista_lang']=list(df['Languages'].str.split(','))
df['Lang_qty']=df['lista_lang'].str.len()

# %%
df['Income'] = df['User_Rating_Count']*1 + df['Price']
# print(df['Income'])

# %%
df['Original_Release_Date']=pd.to_numeric(df['Original Release Date'])
# print(df['Original_Release_Date'])

# %%
df[['Trans_Age',  'Size', 'User_Rating_Count', 'Lang_qty', 'Average_User_Rating', 
    'Original_Release_Date', 'Update', 'Price', 'In-app_Purchases',  'Income']].describe()
# Out:
#           Trans_Age          Size  User_Rating_Count      Lang_qty  \
# count  17007.000000  1.700600e+04       7.561000e+03  16947.000000
# mean       6.204386  1.157064e+08       3.306531e+03      3.260105
# std        3.623524  2.036477e+08       4.232256e+04      6.170621
# min        4.000000  5.132800e+04       5.000000e+00      1.000000
# 25%        4.000000  2.295014e+07       1.200000e+01      1.000000
# 50%        4.000000  5.676895e+07       4.600000e+01      1.000000
# 75%        9.000000  1.330271e+08       3.090000e+02      2.000000
# max       17.000000  4.005591e+09       3.032734e+06    111.000000
#
#        Average_User_Rating  Original_Release_Date        Update         Price  \
# count          7561.000000           1.700700e+04  17007.000000  16983.000000
# mean              4.060905           1.456880e+18    418.034868      0.813419
# std               0.751428           7.240176e+16    691.086181      7.835732
# min               1.000000           1.199750e+18   -333.000000      0.000000
# 25%               3.500000           1.412122e+18      0.000000      0.000000
# 50%               4.500000           1.466381e+18     55.000000      0.000000
# 75%               4.500000           1.512518e+18    581.000000      0.000000
# max               5.000000           1.575677e+18   4086.000000    179.990000
#
#              Income
# count  7.561000e+03
# mean   3.307103e+03
# std    4.232253e+04
# min    5.000000e+00
# 25%    1.300000e+01
# 50%    4.600000e+01
# 75%    3.100000e+02
# max    3.032734e+06

# %%
print(df.Average_User_Rating.quantile(0.3))
print(df.User_Rating_Count.quantile(0.5))
print(df.Trans_Age.quantile(0.80))
print(df.Price.quantile(0.95))
print(df.Income.quantile(0.5))
print(df.Lang_qty.quantile(0.74))
# Out:
# 4.0
# 46.0
# 9.0
# 2.99
# 46.0
# 1.0

# %%
dfd_4_12 =  (df[(df['Price'] < 3) & (df['Average_User_Rating'] >= 4) & (df['Income'] > 46) 
           & (df['User_Rating_Count'] > 46) & (df['Trans_Age'] <= 12)])

age4 = dfd_4_12.corr()
cm = sns.light_palette("green", as_cmap=True)
age4.style.background_gradient(cmap = cm)
# print(age4)
# print()
# print(age4.shape)
# Out:
# <style  type="text/css" >
#     #T_59b03e8a_3a1f_11ea_8251_ec8eb543a598row0_col0 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_59b03e8a_3a1f_11ea_8251_ec8eb543a598row0_col1 {
#             background-color:  #94d294;
#             color:  #000000;
#         }    #T_59b03e8a_3a1f_11ea_8251_ec8eb543a598row0_col2 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_59b03e8a_3a1f_11ea_8251_ec8eb543a598row0_col3 {
#             background-color:  #e3fee3;
#             color:  #000000;
#         }    #T_59b03e8a_3a1f_11ea_8251_ec8eb543a598row0_col4 {
#             background-color:  #a1d9a1;
#             color:  #000000;
#         }    #T_59b03e8a_3a1f_11ea_8251_ec8eb543a598row0_col5 {
#             background-color:  #e4fee4;
#             color:  #000000;
#         }    #T_59b03e8a_3a1f_11ea_8251_ec8eb543a598row0_col6 {
#             background-color:  #c3ecc3;
#             color:  #000000;
#         }    #T_59b03e8a_3a1f_11ea_8251_ec8eb543a598row0_col7 {
#             background-color:  #d3f5d3;
#             color:  #000000;
#         }    #T_59b03e8a_3a1f_11ea_8251_ec8eb543a598row0_col8 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_59b03e8a_3a1f_11ea_8251_ec8eb543a598row0_col9 {
#             background-color:  #048204;
#             color:  #f1f1f1;
#         }    #T_59b03e8a_3a1f_11ea_8251_ec8eb543a598row1_col0 {
#             background-color:  #66b866;
#             color:  #000000;
#         }    #T_59b03e8a_3a1f_11ea_8251_ec8eb543a598row1_col1 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_59b03e8a_3a1f_11ea_8251_ec8eb543a598row1_col2 {
#             background-color:  #d5f6d5;
#             color:  #000000;
#         }    #T_59b03e8a_3a1f_11ea_8251_ec8eb543a598row1_col3 {
#             background-color:  #bce8bc;
#             color:  #000000;
#         }    #T_59b03e8a_3a1f_11ea_8251_ec8eb543a598row1_col4 {
#             background-color:  #caf0ca;
#             color:  #000000;
#         }    #T_59b03e8a_3a1f_11ea_8251_ec8eb543a598row1_col5 {
#             background-color:  #9dd79d;
#             color:  #000000;
#         }    #T_59b03e8a_3a1f_11ea_8251_ec8eb543a598row1_col6 {
#             background-color:  #d8f8d8;
#             color:  #000000;
#         }    #T_59b03e8a_3a1f_11ea_8251_ec8eb543a598row1_col7 {
#             background-color:  #dcfadc;
#             color:  #000000;
#         }    #T_59b03e8a_3a1f_11ea_8251_ec8eb543a598row1_col8 {
#             background-color:  #d5f6d5;
#             color:  #000000;
#         }    #T_59b03e8a_3a1f_11ea_8251_ec8eb543a598row1_col9 {
#             background-color:  #64b764;
#             color:  #000000;
#         }    #T_59b03e8a_3a1f_11ea_8251_ec8eb543a598row2_col0 {
#             background-color:  #90d090;
#             color:  #000000;
#         }    #T_59b03e8a_3a1f_11ea_8251_ec8eb543a598row2_col1 {
#             background-color:  #c2ebc2;
#             color:  #000000;
#         }    #T_59b03e8a_3a1f_11ea_8251_ec8eb543a598row2_col2 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_59b03e8a_3a1f_11ea_8251_ec8eb543a598row2_col3 {
#             background-color:  #bde9bd;
#             color:  #000000;
#         }    #T_59b03e8a_3a1f_11ea_8251_ec8eb543a598row2_col4 {
#             background-color:  #cff3cf;
#             color:  #000000;
#         }    #T_59b03e8a_3a1f_11ea_8251_ec8eb543a598row2_col5 {
#             background-color:  #7dc57d;
#             color:  #000000;
#         }    #T_59b03e8a_3a1f_11ea_8251_ec8eb543a598row2_col6 {
#             background-color:  #d3f5d3;
#             color:  #000000;
#         }    #T_59b03e8a_3a1f_11ea_8251_ec8eb543a598row2_col7 {
#             background-color:  #caf0ca;
#             color:  #000000;
#         }    #T_59b03e8a_3a1f_11ea_8251_ec8eb543a598row2_col8 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_59b03e8a_3a1f_11ea_8251_ec8eb543a598row2_col9 {
#             background-color:  #8ecf8e;
#             color:  #000000;
#         }    #T_59b03e8a_3a1f_11ea_8251_ec8eb543a598row3_col0 {
#             background-color:  #aadeaa;
#             color:  #000000;
#         }    #T_59b03e8a_3a1f_11ea_8251_ec8eb543a598row3_col1 {
#             background-color:  #cdf2cd;
#             color:  #000000;
#         }    #T_59b03e8a_3a1f_11ea_8251_ec8eb543a598row3_col2 {
#             background-color:  #e2fde2;
#             color:  #000000;
#         }    #T_59b03e8a_3a1f_11ea_8251_ec8eb543a598row3_col3 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_59b03e8a_3a1f_11ea_8251_ec8eb543a598row3_col4 {
#             background-color:  #ddfbdd;
#             color:  #000000;
#         }    #T_59b03e8a_3a1f_11ea_8251_ec8eb543a598row3_col5 {
#             background-color:  #68ba68;
#             color:  #000000;
#         }    #T_59b03e8a_3a1f_11ea_8251_ec8eb543a598row3_col6 {
#             background-color:  #d5f6d5;
#             color:  #000000;
#         }    #T_59b03e8a_3a1f_11ea_8251_ec8eb543a598row3_col7 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_59b03e8a_3a1f_11ea_8251_ec8eb543a598row3_col8 {
#             background-color:  #e2fde2;
#             color:  #000000;
#         }    #T_59b03e8a_3a1f_11ea_8251_ec8eb543a598row3_col9 {
#             background-color:  #abdfab;
#             color:  #000000;
#         }    #T_59b03e8a_3a1f_11ea_8251_ec8eb543a598row4_col0 {
#             background-color:  #69ba69;
#             color:  #000000;
#         }    #T_59b03e8a_3a1f_11ea_8251_ec8eb543a598row4_col1 {
#             background-color:  #c1ebc1;
#             color:  #000000;
#         }    #T_59b03e8a_3a1f_11ea_8251_ec8eb543a598row4_col2 {
#             background-color:  #d9f8d9;
#             color:  #000000;
#         }    #T_59b03e8a_3a1f_11ea_8251_ec8eb543a598row4_col3 {
#             background-color:  #c2ecc2;
#             color:  #000000;
#         }    #T_59b03e8a_3a1f_11ea_8251_ec8eb543a598row4_col4 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_59b03e8a_3a1f_11ea_8251_ec8eb543a598row4_col5 {
#             background-color:  #95d395;
#             color:  #000000;
#         }    #T_59b03e8a_3a1f_11ea_8251_ec8eb543a598row4_col6 {
#             background-color:  #95d395;
#             color:  #000000;
#         }    #T_59b03e8a_3a1f_11ea_8251_ec8eb543a598row4_col7 {
#             background-color:  #c4edc4;
#             color:  #000000;
#         }    #T_59b03e8a_3a1f_11ea_8251_ec8eb543a598row4_col8 {
#             background-color:  #d9f8d9;
#             color:  #000000;
#         }    #T_59b03e8a_3a1f_11ea_8251_ec8eb543a598row4_col9 {
#             background-color:  #62b662;
#             color:  #000000;
#         }    #T_59b03e8a_3a1f_11ea_8251_ec8eb543a598row5_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_59b03e8a_3a1f_11ea_8251_ec8eb543a598row5_col1 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_59b03e8a_3a1f_11ea_8251_ec8eb543a598row5_col2 {
#             background-color:  #caf0ca;
#             color:  #000000;
#         }    #T_59b03e8a_3a1f_11ea_8251_ec8eb543a598row5_col3 {
#             background-color:  #8cce8c;
#             color:  #000000;
#         }    #T_59b03e8a_3a1f_11ea_8251_ec8eb543a598row5_col4 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_59b03e8a_3a1f_11ea_8251_ec8eb543a598row5_col5 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_59b03e8a_3a1f_11ea_8251_ec8eb543a598row5_col6 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_59b03e8a_3a1f_11ea_8251_ec8eb543a598row5_col7 {
#             background-color:  #cdf2cd;
#             color:  #000000;
#         }    #T_59b03e8a_3a1f_11ea_8251_ec8eb543a598row5_col8 {
#             background-color:  #caf0ca;
#             color:  #000000;
#         }    #T_59b03e8a_3a1f_11ea_8251_ec8eb543a598row5_col9 {
#             background-color:  #e5ffe5;
#             color:  #000000;

# %%
my_figure = sns.pairplot(age4)
print(my_figure)
# my_figure.savefig(os.path.join(os.path.abspath(""), "Age_4_12_corr.png"))
# Out:
# <seaborn.axisgrid.PairGrid object at 0x000001CE01BDCD08>

# %%
dfd_12_17 =  (df[(df['Price'] < 3) & (df['Average_User_Rating'] >= 4) & (df['Income'] > 46) 
           & (df['User_Rating_Count'] > 46) & (df['Trans_Age'] >= 12)])

age12 = dfd_12_17.corr()
cm = sns.light_palette("green", as_cmap=True)
age12.style.background_gradient(cmap = cm)
# print(age12)
# print()
# print(age12.shape)
# Out:
# <style  type="text/css" >
#     #T_655bbff8_3a1f_11ea_b0ad_ec8eb543a598row0_col0 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_655bbff8_3a1f_11ea_b0ad_ec8eb543a598row0_col1 {
#             background-color:  #9dd79d;
#             color:  #000000;
#         }    #T_655bbff8_3a1f_11ea_b0ad_ec8eb543a598row0_col2 {
#             background-color:  #dcfadc;
#             color:  #000000;
#         }    #T_655bbff8_3a1f_11ea_b0ad_ec8eb543a598row0_col3 {
#             background-color:  #e4fee4;
#             color:  #000000;
#         }    #T_655bbff8_3a1f_11ea_b0ad_ec8eb543a598row0_col4 {
#             background-color:  #ade0ad;
#             color:  #000000;
#         }    #T_655bbff8_3a1f_11ea_b0ad_ec8eb543a598row0_col5 {
#             background-color:  #e3fee3;
#             color:  #000000;
#         }    #T_655bbff8_3a1f_11ea_b0ad_ec8eb543a598row0_col6 {
#             background-color:  #caf0ca;
#             color:  #000000;
#         }    #T_655bbff8_3a1f_11ea_b0ad_ec8eb543a598row0_col7 {
#             background-color:  #bce8bc;
#             color:  #000000;
#         }    #T_655bbff8_3a1f_11ea_b0ad_ec8eb543a598row0_col8 {
#             background-color:  #dcfadc;
#             color:  #000000;
#         }    #T_655bbff8_3a1f_11ea_b0ad_ec8eb543a598row0_col9 {
#             background-color:  #058305;
#             color:  #f1f1f1;
#         }    #T_655bbff8_3a1f_11ea_b0ad_ec8eb543a598row1_col0 {
#             background-color:  #67b967;
#             color:  #000000;
#         }    #T_655bbff8_3a1f_11ea_b0ad_ec8eb543a598row1_col1 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_655bbff8_3a1f_11ea_b0ad_ec8eb543a598row1_col2 {
#             background-color:  #c2ecc2;
#             color:  #000000;
#         }    #T_655bbff8_3a1f_11ea_b0ad_ec8eb543a598row1_col3 {
#             background-color:  #bae7ba;
#             color:  #000000;
#         }    #T_655bbff8_3a1f_11ea_b0ad_ec8eb543a598row1_col4 {
#             background-color:  #ccf1cc;
#             color:  #000000;
#         }    #T_655bbff8_3a1f_11ea_b0ad_ec8eb543a598row1_col5 {
#             background-color:  #95d395;
#             color:  #000000;
#         }    #T_655bbff8_3a1f_11ea_b0ad_ec8eb543a598row1_col6 {
#             background-color:  #d6f7d6;
#             color:  #000000;
#         }    #T_655bbff8_3a1f_11ea_b0ad_ec8eb543a598row1_col7 {
#             background-color:  #d1f4d1;
#             color:  #000000;
#         }    #T_655bbff8_3a1f_11ea_b0ad_ec8eb543a598row1_col8 {
#             background-color:  #c2ecc2;
#             color:  #000000;
#         }    #T_655bbff8_3a1f_11ea_b0ad_ec8eb543a598row1_col9 {
#             background-color:  #66b866;
#             color:  #000000;
#         }    #T_655bbff8_3a1f_11ea_b0ad_ec8eb543a598row2_col0 {
#             background-color:  #88cb88;
#             color:  #000000;
#         }    #T_655bbff8_3a1f_11ea_b0ad_ec8eb543a598row2_col1 {
#             background-color:  #b6e5b6;
#             color:  #000000;
#         }    #T_655bbff8_3a1f_11ea_b0ad_ec8eb543a598row2_col2 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_655bbff8_3a1f_11ea_b0ad_ec8eb543a598row2_col3 {
#             background-color:  #bae7ba;
#             color:  #000000;
#         }    #T_655bbff8_3a1f_11ea_b0ad_ec8eb543a598row2_col4 {
#             background-color:  #a8dda8;
#             color:  #000000;
#         }    #T_655bbff8_3a1f_11ea_b0ad_ec8eb543a598row2_col5 {
#             background-color:  #7bc47b;
#             color:  #000000;
#         }    #T_655bbff8_3a1f_11ea_b0ad_ec8eb543a598row2_col6 {
#             background-color:  #c2ebc2;
#             color:  #000000;
#         }    #T_655bbff8_3a1f_11ea_b0ad_ec8eb543a598row2_col7 {
#             background-color:  #b8e6b8;
#             color:  #000000;
#         }    #T_655bbff8_3a1f_11ea_b0ad_ec8eb543a598row2_col8 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_655bbff8_3a1f_11ea_b0ad_ec8eb543a598row2_col9 {
#             background-color:  #86ca86;
#             color:  #000000;
#         }    #T_655bbff8_3a1f_11ea_b0ad_ec8eb543a598row3_col0 {
#             background-color:  #aee0ae;
#             color:  #000000;
#         }    #T_655bbff8_3a1f_11ea_b0ad_ec8eb543a598row3_col1 {
#             background-color:  #d7f7d7;
#             color:  #000000;
#         }    #T_655bbff8_3a1f_11ea_b0ad_ec8eb543a598row3_col2 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_655bbff8_3a1f_11ea_b0ad_ec8eb543a598row3_col3 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_655bbff8_3a1f_11ea_b0ad_ec8eb543a598row3_col4 {
#             background-color:  #daf9da;
#             color:  #000000;
#         }    #T_655bbff8_3a1f_11ea_b0ad_ec8eb543a598row3_col5 {
#             background-color:  #65b865;
#             color:  #000000;
#         }    #T_655bbff8_3a1f_11ea_b0ad_ec8eb543a598row3_col6 {
#             background-color:  #defbde;
#             color:  #000000;
#         }    #T_655bbff8_3a1f_11ea_b0ad_ec8eb543a598row3_col7 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_655bbff8_3a1f_11ea_b0ad_ec8eb543a598row3_col8 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_655bbff8_3a1f_11ea_b0ad_ec8eb543a598row3_col9 {
#             background-color:  #ade0ad;
#             color:  #000000;
#         }    #T_655bbff8_3a1f_11ea_b0ad_ec8eb543a598row4_col0 {
#             background-color:  #70be70;
#             color:  #000000;
#         }    #T_655bbff8_3a1f_11ea_b0ad_ec8eb543a598row4_col1 {
#             background-color:  #c8efc8;
#             color:  #000000;
#         }    #T_655bbff8_3a1f_11ea_b0ad_ec8eb543a598row4_col2 {
#             background-color:  #b0e2b0;
#             color:  #000000;
#         }    #T_655bbff8_3a1f_11ea_b0ad_ec8eb543a598row4_col3 {
#             background-color:  #b9e7b9;
#             color:  #000000;
#         }    #T_655bbff8_3a1f_11ea_b0ad_ec8eb543a598row4_col4 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_655bbff8_3a1f_11ea_b0ad_ec8eb543a598row4_col5 {
#             background-color:  #93d193;
#             color:  #000000;
#         }    #T_655bbff8_3a1f_11ea_b0ad_ec8eb543a598row4_col6 {
#             background-color:  #dbf9db;
#             color:  #000000;
#         }    #T_655bbff8_3a1f_11ea_b0ad_ec8eb543a598row4_col7 {
#             background-color:  #bce8bc;
#             color:  #000000;
#         }    #T_655bbff8_3a1f_11ea_b0ad_ec8eb543a598row4_col8 {
#             background-color:  #b0e2b0;
#             color:  #000000;
#         }    #T_655bbff8_3a1f_11ea_b0ad_ec8eb543a598row4_col9 {
#             background-color:  #67b967;
#             color:  #000000;
#         }    #T_655bbff8_3a1f_11ea_b0ad_ec8eb543a598row5_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_655bbff8_3a1f_11ea_b0ad_ec8eb543a598row5_col1 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_655bbff8_3a1f_11ea_b0ad_ec8eb543a598row5_col2 {
#             background-color:  #cbf1cb;
#             color:  #000000;
#         }    #T_655bbff8_3a1f_11ea_b0ad_ec8eb543a598row5_col3 {
#             background-color:  #86ca86;
#             color:  #000000;
#         }    #T_655bbff8_3a1f_11ea_b0ad_ec8eb543a598row5_col4 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_655bbff8_3a1f_11ea_b0ad_ec8eb543a598row5_col5 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_655bbff8_3a1f_11ea_b0ad_ec8eb543a598row5_col6 {
#             background-color:  #d5f6d5;
#             color:  #000000;
#         }    #T_655bbff8_3a1f_11ea_b0ad_ec8eb543a598row5_col7 {
#             background-color:  #c3ecc3;
#             color:  #000000;
#         }    #T_655bbff8_3a1f_11ea_b0ad_ec8eb543a598row5_col8 {
#             background-color:  #cbf1cb;
#             color:  #000000;
#         }    #T_655bbff8_3a1f_11ea_b0ad_ec8eb543a598row5_col9 {
#             background-color:  #e5ffe5;
#             color:  #000000;

# %%
my_figure1 = sns.pairplot(age12)
print(my_figure1)
# my_figure1.savefig(os.path.join(os.path.abspath(""), "Age_12_17_corr.png"))
# Out:
# <seaborn.axisgrid.PairGrid object at 0x000001CE084C0608>

# %%
sns.set_style('white')
sns.set_style('ticks')
nazwax = sns.regplot(x = 'User_Rating_Count', y = 'Income', color = 'g', data = age12)
nazwa1 = nazwax.get_figure()
print(nazwa1)
# nazwa1.savefig(os.path.join(os.path.abspath(""), "nazwa1.png"))
# Out:
# Figure(432x288)

# %%
sns.set_style('white')
sns.set_style('ticks')
nazway = sns.regplot(x = 'Original_Release_Date', y = 'Update', color = 'g', data = age12)
nazwa2 = nazwax.get_figure()
print(nazwa2)
# nazwa2.savefig(os.path.join(os.path.abspath(""), "nazwa2.png"))
# Out:
# Figure(432x288)

# %%
# No to trzeba zastanowić sie co wybrać i wygenerowac wykresy
