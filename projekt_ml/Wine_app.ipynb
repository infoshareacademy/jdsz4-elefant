# %%
from PyQt5.QtWidgets import QApplication, QPushButton, QMainWindow, QDialog, QGroupBox, QHBoxLayout, QVBoxLayout, \
    QGridLayout, QInputDialog, QLabel, QRadioButton, QLineEdit, QWidget,QSlider,QSpinBox,QMenuBar
import sys
from PyQt5 import QtGui
from PyQt5 import QtCore
from PyQt5.QtCore import Qt
import numpy as np
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from scipy import stats


df=pd.read_csv('/home/messq/PycharmProjects/untitled13/winequality-red.csv')
z = np.abs(stats.zscore(df))
threshold = 4
df = df[(z<threshold).all(axis=1)]
y=df['quality'].values
x=df.iloc[:,[0,1,2,4,5,6,7,8,9,10]].values
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2,random_state=42)


class Window(QDialog):
    def __init__(self):
        super().__init__()

        self.title = 'Wine_Classifier'
        self.top = 300
        self.left = 500
        self.width = 2000
        self.height = 1200


        self.setWindowIcon(QtGui.QIcon('/home/messq/PycharmProjects/untitled13/winico.png'))
        self.setWindowTitle(self.title)
        self.setGeometry(self.left, self.top, self.width, self.height)
        self.setStyleSheet('background-color:lavenderblush')

        self.createlayout()
        vbox = QVBoxLayout()
        vbox.addWidget(self.groupbox)



        self.setLayout(vbox)
        self.show()


    def changedslider(self):
        size = self.slider.value()
        self.labels.setText(str(size/10))

    def changedslider2(self):
        size = self.slider2.value()
        self.labels2.setText(str(size/100))

    def changedslider3(self):
        size = self.slider3.value()
        self.labels3.setText(str(size/100))

    def changedslider4(self):
        size = self.slider4.value()
        self.labels4.setText(str(size/1000))

    def changedslider5(self):
        size = self.slider5.value()
        self.labels5.setText(str(size))

    def changedslider6(self):
        size = self.slider6.value()
        self.labels6.setText(str(size))

    def changedslider7(self):
        size = self.slider7.value()
        self.labels7.setText(str(size/10000))

    def changedslider8(self):
        size = self.slider8.value()
        self.labels8.setText(str(size/100))

    def changedslider9(self):
        size = self.slider9.value()
        self.labels9.setText(str(size/100))

    def changedslider10(self):
        size = self.slider10.value()
        self.labels10.setText(str(size/10))

    def lololo(self):
        classifier = RandomForestClassifier(random_state=82)
        classifier.fit(x_train, y_train)
        predyk = classifier.predict([[self.slider.value()/10,self.slider2.value()/100,self.slider3.value()/100,self.slider4.value()/1000,self.slider5.value(),self.slider6.value(),self.slider7.value()/10000,self.slider8.value()/100,self.slider9.value()/100,self.slider10.value()/10]])
        self.labelw.setText('Your wine is classify as: '+str(predyk[0]))

    def createlayout(self):
        self.groupbox = QGroupBox()
        # self.groupbox.setFont(QtGui.QFont('Sanserif', 15))
        # self.groupbox.setStyleSheet("QGroupBox { background-color: rgb(255, 30,30); border:1px solid rgb(0, 0, 0); }")
        gridlayout = QGridLayout()



        label = QLabel('Fixed Acidity:')
        label.setFont(QtGui.QFont('Sanserif', 25))
        label.setStyleSheet('color:crimson')
        gridlayout.addWidget(label, 0, 0,1,2)

        self.slider = QSlider()
        self.slider.setOrientation(Qt.Horizontal)
        self.slider.setTickPosition(QSlider.TicksBelow)
        self.slider.setTickInterval(1)
        self.slider.setMinimum(45)
        self.slider.setMaximum(150)
        self.slider.setValue(100)
        self.slider.valueChanged.connect(self.changedslider)
        gridlayout.addWidget(self.slider, 0,2,1,3)

        slider_style = "QSlider::groove:horizontal {\
            border: 1px solid #999999;\
            height: 8px; \
            background-color: qlineargradient(spread:pad, x1:0, y1:0, x2:1, y2:0, stop:0 white, stop:0.20833333333333334 white, stop:0.25 magenta, stop:0.4583333333333333 magenta, stop:0.5 red, stop:0.7083333333333334 red, stop:0.75 purple, stop:1 purple);\
            margin: -4px 0;\
            }QSlider::handle:horizontal {\
            background-color: black;\
            border: 1px solid #5c5c5c;\
            border-radius: 0px;\
            border-color: black;\
            height: 8px;\
            width: 6px;\
            margin: -8px 2; \
            }"

        self.slider.setStyleSheet(slider_style)

        self.labels=QLabel('10')
        self.labels.setFont(QtGui.QFont('Sanserif', 20))
        self.labels.setStyleSheet('color:red')
        gridlayout.addWidget(self.labels, 1, 3)


        label2 = QLabel('Volatile acidity:')
        label2.setFont(QtGui.QFont('Sanserif', 25))
        label2.setStyleSheet('color:crimson')
        gridlayout.addWidget(label2, 0, 5,1,2)

        self.slider2 = QSlider()
        self.slider2.setOrientation(Qt.Horizontal)
        self.slider2.setTickPosition(QSlider.TicksBelow)
        self.slider2.setTickInterval(1)
        self.slider2.setMinimum(12)
        self.slider2.setMaximum(124)
        self.slider2.setValue(60)
        self.slider2.valueChanged.connect(self.changedslider2)
        self.slider2.setStyleSheet(slider_style)
        gridlayout.addWidget(self.slider2, 0, 7,1,3)

        self.labels2 = QLabel('0.6')
        self.labels2.setFont(QtGui.QFont('Sanserif', 20))
        self.labels2.setStyleSheet('color:red')
        gridlayout.addWidget(self.labels2, 1, 8)

        label3 = QLabel('Citric acid:')
        label3.setFont(QtGui.QFont('Sanserif', 25))
        label3.setStyleSheet('color:crimson')
        gridlayout.addWidget(label3, 2, 0,1,2)

        self.slider3 = QSlider()
        self.slider3.setOrientation(Qt.Horizontal)
        self.slider3.setTickPosition(QSlider.TicksBelow)
        self.slider3.setTickInterval(1)
        self.slider3.setMinimum(0)
        self.slider3.setMaximum(80)
        self.slider3.setValue(25)
        self.slider3.valueChanged.connect(self.changedslider3)
        self.slider3.setStyleSheet(slider_style)
        gridlayout.addWidget(self.slider3,2,2,1,3)

        self.labels3 = QLabel('0.25')
        self.labels3.setFont(QtGui.QFont('Sanserif', 20))
        self.labels3.setStyleSheet('color:red')
        gridlayout.addWidget(self.labels3,3, 3)


        label4 = QLabel('Chlorides:')
        label4.setFont(QtGui.QFont('Sanserif', 25))
        label4.setStyleSheet('color:crimson')
        gridlayout.addWidget(label4, 2, 5,1,2)

        self.slider4 = QSlider()
        self.slider4.setOrientation(Qt.Horizontal)
        self.slider4.setTickPosition(QSlider.TicksBelow)
        self.slider4.setTickInterval(1)
        self.slider4.setMinimum(12)
        self.slider4.setMaximum(270)
        self.slider4.setValue(80)
        self.slider4.valueChanged.connect(self.changedslider4)
        self.slider4.setStyleSheet(slider_style)
        gridlayout.addWidget(self.slider4, 2, 7,1,3)

        self.labels4 = QLabel('0.08')
        self.labels4.setFont(QtGui.QFont('Sanserif', 20))
        self.labels4.setStyleSheet('color:red')
        gridlayout.addWidget(self.labels4, 3, 8)


        label5 = QLabel('Free sulfur dioxide:')
        label5.setFont(QtGui.QFont('Sanserif', 25))
        label5.setStyleSheet('color:crimson')
        gridlayout.addWidget(label5, 4, 0, 1, 2)

        self.slider5 = QSlider()
        self.slider5.setOrientation(Qt.Horizontal)
        self.slider5.setTickPosition(QSlider.TicksBelow)
        self.slider5.setTickInterval(1)
        self.slider5.setMinimum(1)
        self.slider5.setMaximum(57)
        self.slider5.setValue(15)
        self.slider5.valueChanged.connect(self.changedslider5)
        self.slider5.setStyleSheet(slider_style)
        gridlayout.addWidget(self.slider5,4,2,1,3)

        self.labels5 = QLabel('15')
        self.labels5.setFont(QtGui.QFont('Sanserif', 20))
        self.labels5.setStyleSheet('color:red')
        gridlayout.addWidget(self.labels5,5, 3)

        label6 = QLabel('Total sulfur dioxide:')
        label6.setFont(QtGui.QFont('Sanserif', 25))
        label6.setStyleSheet('color:crimson')
        gridlayout.addWidget(label6, 4, 5,1,2)

        self.slider6 = QSlider()
        self.slider6.setOrientation(Qt.Horizontal)
        self.slider6.setTickPosition(QSlider.TicksBelow)
        self.slider6.setTickInterval(1)
        self.slider6.setMinimum(6)
        self.slider6.setMaximum(165)
        self.slider6.setValue(50)
        self.slider6.valueChanged.connect(self.changedslider6)
        self.slider6.setStyleSheet(slider_style)
        gridlayout.addWidget(self.slider6, 4, 7,1,3)

        self.labels6 = QLabel('50')
        self.labels6.setFont(QtGui.QFont('Sanserif', 20))
        self.labels6.setStyleSheet('color:red')
        gridlayout.addWidget(self.labels6, 5, 8)

        label7 = QLabel('Density:')
        label7.setFont(QtGui.QFont('Sanserif', 25))
        label7.setStyleSheet('color:crimson')
        gridlayout.addWidget(label7, 6, 0, 1, 2)

        self.slider7 = QSlider()
        self.slider7.setOrientation(Qt.Horizontal)
        self.slider7.setTickPosition(QSlider.TicksBelow)
        self.slider7.setTickInterval(1)
        self.slider7.setMinimum(9901)
        self.slider7.setMaximum(10029)
        self.slider7.setValue(9967)
        self.slider7.valueChanged.connect(self.changedslider7)
        self.slider7.setStyleSheet(slider_style)
        gridlayout.addWidget(self.slider7,6,2,1,3)

        self.labels7 = QLabel('0.9967')
        self.labels7.setFont(QtGui.QFont('Sanserif', 20))
        self.labels7.setStyleSheet('color:red')
        gridlayout.addWidget(self.labels7,7, 3)

        label8 = QLabel('pH:')
        label8.setFont(QtGui.QFont('Sanserif', 25))
        label8.setStyleSheet('color:crimson')
        gridlayout.addWidget(label8, 6, 5,1,2)

        self.slider8 = QSlider()
        self.slider8.setOrientation(Qt.Horizontal)
        self.slider8.setTickPosition(QSlider.TicksBelow)
        self.slider8.setTickInterval(1)
        self.slider8.setMinimum(286)
        self.slider8.setMaximum(390)
        self.slider8.setValue(331)
        self.slider8.valueChanged.connect(self.changedslider8)
        self.slider8.setStyleSheet(slider_style)
        gridlayout.addWidget(self.slider8, 6, 7, 1, 3)

        self.labels8 = QLabel('3.31')
        self.labels8.setFont(QtGui.QFont('Sanserif', 20))
        self.labels8.setStyleSheet('color:red')
        gridlayout.addWidget(self.labels8, 7, 8)

        label9 = QLabel('Sulphates:')
        label9.setFont(QtGui.QFont('Sanserif', 25))
        label9.setStyleSheet('color:crimson')
        gridlayout.addWidget(label9, 8, 0, 1, 2)

        self.slider9 = QSlider()
        self.slider9.setOrientation(Qt.Horizontal)
        self.slider9.setTickPosition(QSlider.TicksBelow)
        self.slider9.setTickInterval(1)
        self.slider9.setMinimum(30)
        self.slider9.setMaximum(125)
        self.slider9.setValue(62)
        self.slider9.valueChanged.connect(self.changedslider9)
        self.slider9.setStyleSheet(slider_style)
        gridlayout.addWidget(self.slider9, 8, 2, 1, 3)

        self.labels9 = QLabel('0.62')
        self.labels9.setFont(QtGui.QFont('Sanserif', 20))
        self.labels9.setStyleSheet('color:red')
        gridlayout.addWidget(self.labels9, 9, 3)


        label10 = QLabel('Alcohol:')
        label10.setFont(QtGui.QFont('Sanserif', 25))
        label10.setStyleSheet('color:crimson')
        gridlayout.addWidget(label10, 8, 5,1,2)

        self.slider10 = QSlider()
        self.slider10.setOrientation(Qt.Horizontal)
        self.slider10.setTickPosition(QSlider.TicksBelow)
        self.slider10.setTickInterval(1)
        self.slider10.setMinimum(80)
        self.slider10.setMaximum(160)
        self.slider10.setValue(120)
        self.slider10.valueChanged.connect(self.changedslider10)
        self.slider10.setStyleSheet(slider_style)
        gridlayout.addWidget(self.slider10, 8, 7, 1, 3)

        self.labels10 = QLabel('12')
        self.labels10.setFont(QtGui.QFont('Sanserif', 20))
        self.labels10.setStyleSheet('color:red')
        gridlayout.addWidget(self.labels10, 9, 8)

        self.labelw = QLabel(self)
        self.labelw.setFont(QtGui.QFont('Sanserif', 25))
        self.labelw.setStyleSheet('color:crimson')
        gridlayout.addWidget(self.labelw, 10,4,1,2)

        button = QPushButton()
        button.setText('Classify my Wine!')
        button.setFont(QtGui.QFont('Sanserif', 20))
        button.setStyleSheet("background-color: red")
        button.setIcon(QtGui.QIcon('/home/messq/PycharmProjects/untitled13/winico.png'))
        button.setIconSize(QtCore.QSize(50, 100))
        button.setToolTip('<h4>Click this button to see a classification of your wine!<h4>')
        button.clicked.connect(self.lololo)
        button.setMinimumHeight(40)
        gridlayout.addWidget(button, 15, 0 ,1,10)

        button1 = QPushButton()
        button1.setText('Close app')
        button1.setFont(QtGui.QFont('Sanserif', 20))
        button1.setStyleSheet("background-color: red")
        button1.setIcon(QtGui.QIcon('/home/messq/PycharmProjects/untitled13/winser.png'))
        button1.setIconSize(QtCore.QSize(50, 50))
        button1.setToolTip('<h4>Click this button to close the app!<h4>')
        button1.clicked.connect(self.click_me)
        button1.setMinimumHeight(40)
        gridlayout.addWidget(button1, 16, 2,1,6)


        self.groupbox.setLayout(gridlayout)



    def click_me(self):
        sys.exit()


if __name__ == '__main__':
    App = QApplication(sys.argv)
    window = Window()
    sys.exit(App.exec())
